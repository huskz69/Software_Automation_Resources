# %% [markdown]
# # Week 0 - Problem Set: Fundamentals of Machine Learning
#
# Practice what you learned about the fundamentals of Machine Learning with these problems.
#
# *Instructions: For each question, double-click the designated **Answer** cell below it to type your response. Press `Shift + Enter` to render the text when you are finished.*

# %% [markdown]
# ---
# ## Part 1: Traditional Programming vs. Machine Learning
# First, let's look at how computers solve problems with traditional programming versus how they solve them using machine learning.

# %% [markdown]
# __1. Create an IPO (Input-Process-Output) table for a traditional algorithm that converts Celsius to Fahrenheit.__
#
# Hint: The formula is `F = (C × 9/5) + 32`

# %% [markdown]
# **Answer 1:**
#
# | Input | Process | Output |
# |---|---|---|
# | *Type here* | *Type here* | *Type here* |

# %% [markdown]
# __2. Create an IPO table for a machine learning model that learns to predict temperature conversions. How does the "Input" differ from the traditional algorithm above?__

# %% [markdown]
# **Answer 2:**
#
# | Input | Process | Output |
# |---|---|---|
# | *Type here* | *Type here* | *Type here* |
#
# **Explanation of Difference:**
# > *Type your explanation here...*

# %% [markdown]
# __3. Complete the table comparing Traditional Programming and Machine Learning:__

# %% [markdown]
# **Answer 3:**
#
# | Aspect | Traditional Programming | Machine Learning |
# |--------|------------------------|------------------|
# | How rules are created | Written by humans | ? |
# | Outputs | Deterministic | ? |
# | Can improve without reprogramming | No | ? |
# | Transparency | ? | Often a black box |
# | Best for | Problems with clear rules | ? |

# %% [markdown]
# __4. Run the code below. Then, explain why the ML model doesn't give exactly 6 as the answer, even though 4 + 2 = 6.__

# %%
import numpy as np
from sklearn.linear_model import LinearRegression

# Training data
X = np.array([[1, 1], [2, 2], [3, 1], [5, 3]])
y = np.array([2, 4, 4, 8])

model = LinearRegression()
model.fit(X, y)

prediction = model.predict([[4, 2]])[0]
print(f"ML Model says 4 + 2 = {prediction:.4f}")
print(f"Actual answer: 4 + 2 = 6")

# %% [markdown]
# **Answer 4:**
#
# > *Type your explanation here...*

# %% [markdown]
# ---
# ## Part 2: The "Black Box" and Data
# Because machine learning models learn patterns rather than following strict human-written rules, they can sometimes be difficult to understand.

# %% [markdown]
# __5. Explain in your own words what a "black box" means in the context of machine learning. Give one specific reason why this lack of transparency might be a problem in the real world.__

# %% [markdown]
# **Answer 5:**
#
# > *Type your answer here...*

# %% [markdown]
# ---
# ## Part 3: Understanding Bias
# If a model is a "black box," we have to be very careful about the data we put into it. "Garbage in, garbage out" is a common phrase in data science. When the input data is flawed, the model's predictions will be biased.

# %% [markdown]
# __6. Historical Bias:__ A company wants to build a machine learning model to predict which job applicants to interview. They plan to train it on 5 years of historical hiring data. Identify TWO potential sources of bias in this approach.

# %% [markdown]
# **Answer 6:**
#
# 1. *Type your first point here...*
# 2. *Type your second point here...*

# %% [markdown]
# __7. Representation Bias:__ A facial recognition system is trained primarily on images of people with light skin. What type of bias is this, and what real-world problems might it cause?

# %% [markdown]
# **Answer 7:**
#
# > *Type your answer here...*

# %% [markdown]
# __8. Proxy Bias:__ Consider the following scenario:
#
# A hospital uses a machine learning model to predict which patients need urgent care. The model was trained on historical data where patients from wealthier areas received more tests and therefore had more documented health issues.
#
# a) What type of bias might this model have?
# b) How might this affect patients from less wealthy areas?
# c) What ethical principle is being violated?

# %% [markdown]
# **Answer 8:**
#
# **a)** *Type here...*
#
# **b)** *Type here...*
#
# **c)** *Type here...*

# %% [markdown]
# ---
# ## Part 4: Ethics and Accountability
# Knowing that these systems can fail or be biased, data scientists must follow ethical principles.

# %% [markdown]
# __9. Match each ethical principle with its correct description:__
#
# | Principle | Description |
# |-----------|-------------|
# | A. Fairness | 1. Decisions can be explained and understood |
# | B. Transparency | 2. Someone is responsible for the model's outcomes |
# | C. Accountability | 3. Personal information is protected |
# | D. Privacy | 4. Model treats all groups equitably |

# %% [markdown]
# **Answer 9:**
#
# * **A** matches with: [ *Type number* ]
# * **B** matches with: [ *Type number* ]
# * **C** matches with: [ *Type number* ]
# * **D** matches with: [ *Type number* ]

# %% [markdown]
# __10. Case Study: Predictive Policing__
#
# A city implements a machine learning system to predict where crimes are likely to occur. The system is trained on historical arrest data from the past 10 years. Police are then sent to patrol areas the model predicts will have high crime.
#
# a) If certain neighborhoods have historically been over-policed (more police presence leading to more arrests), how might this affect the model's predictions?
# b) Could this create a feedback loop? Explain how.
# c) What questions should be asked before deploying such a system?
# d) Who should be accountable if the system leads to unfair outcomes?

# %% [markdown]
# **Answer 10:**
#
# **a)** *Type here...*
#
# **b)** *Type here...*
#
# **c)** *Type here...*
#
# **d)** *Type here...*

# %% [markdown]
# __11. EXTENSION: Independent Research__
#
# Research one real-world example of bias in a machine learning system (not mentioned in this lesson). Write a short paragraph describing:
# - What the system was designed to do.
# - What bias was discovered.
# - What the consequences were.
# - How it could have been prevented.

# %% [markdown]
# **Answer 11:**
#
# > *Type your research paragraph here...*
